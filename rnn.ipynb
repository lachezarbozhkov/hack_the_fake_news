# %%
import numpy as np
np.random.seed(1337)  # for reproducibility
import pandas as pd

import keras
from keras.preprocessing import sequence
from keras.models import Sequential, Model
from keras.layers import Dense, Activation, Embedding, Conv1D, MaxPooling1D, GlobalMaxPool1D, Dropout, Input, Masking, TimeDistributed
from keras.layers import LSTM, GRU
from keras.datasets import imdb
from keras.preprocessing.text import Tokenizer
from keras.callbacks import TensorBoard, ModelCheckpoint
from keras.layers.wrappers import Bidirectional
from keras.layers.merge import Concatenate


from sklearn.externals import joblib
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder, LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle


import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
filters = '!"#%&()*+,-./:;<=>?@[\]^_`{|}~\'„““-–«' + '0123456789' + '\t\n\r'

# %%
data = pd.read_excel('data/FN_Training_Set.xlsx')
train, test = train_test_split(data, test_size=0.1, random_state=999)
train = train.dropna(subset=['Content'])

# %%
## train tokenizer

tokenizer = Tokenizer(num_words=10000, filters=filters, lower=True, split=" ")
print('fit on ', len(train))
tokenizer.fit_on_texts(train.Content)
print('tokens', len(tokenizer.word_counts))

# ## save tokenizer
# joblib.dump(tokenizer, 'tokenizer')

## load tokenizer
# tokenizer = joblib.load('tokenizer')

# ## check some words:
tokenizer.texts_to_sequences(['здравей Бойко'])
# [[61, 61, 33, 531, 5, 5, 5]]
# Out:
# fit on  2525
# tokens 94022
# [[526]]

# %%
tokenizer.word_counts
# Out:
# {'бунтует': 2,
#  'webcafe': 1,
#  'наложите': 4,
#  'спонсорирал': 4,
#  'фамозният': 1,
#  'lawyer': 2,
#  'связан': 2,
#  'гeнepaл': 1,
#  'спомени\xa0от': 2,
#  'запален': 5,
#  'депривация': 1,
#  'помагала': 43,
#  'принизят': 1,
#  'възклицавам': 1,
#  'комбинация\xa0iv\xa0от': 1,
#  'предоставящ': 1,
#  'преброи': 2,
#  'чуждестранните': 7,
#  'от\xa0': 78,
#  'teroristi': 1,
#  'усмихвай': 2,
#  'набелязания': 2,
#  'адресите': 2,
#  'военнaта\xa0база': 1,
#  'раздавани': 2,
#  'наемът': 1,
#  'насилие”': 1,
#  'мийте': 1,
#  'кондратиев': 4,
#  'негър': 1,
#  'дискутирали': 3,
#  '\xa0заключение\xa0това': 1,
#  'кракът': 36,
#  'противоположни': 7,
#  'химични': 5,
#  'агенти”': 1,
#  'цвета': 15,
#  'бойкотирали': 1,
#  'термин': 22,
#  'програмни': 3,
#  'новината”': 3,
#  'техният': 72,
#  'болежка': 2,
#  'приета': 28,
#  'випуск': 3,
#  'стандартность': 2,
#  'радиологична': 4,
#  'пережил': 1,
#  'изобразил': 1,
#  'магьосници”': 2,
#  'хранилището': 1,
#  'дипломатической': 3,
#  'антисъветска': 1,
#  'мечока': 3,
#  'испанската': 3,
#  'мобилните': 5,
#  'гяурина”': 1,
#  'маркета': 2,
#  'хълмисти': 1,
#  'разкарахме': 1,
#  'гузен': 1,
#  'cassani': 1,
#  'мария\xa0безгранично': 1,
#  'гранитни': 5,
#  'паника': 52,
#  'пирин': 75,
#  'открития': 40,
#  'фриволното': 2,
#  'магьосникъът': 1,
#  'незряло': 1,
#  'геноцидно': 1,
#  'неживой': 2,
#  'съглася': 1,
#  'всичко”': 5,
#  'обяснявала': 10,
#  '\xa0когато': 11,
#  'държавите': 123,
#  'юдейският': 10,
#  'общуване\xa0': 1,
#  'емулсирането': 9,
#  'светеца': 13,
#  'непубликуваната\xa0изповед': 1,
#  'ракетами': 1,
#  'вътрешнополитически': 9,
#  'некомпетентност': 3,
#  'ставки': 15,
#  'применением': 2,
#  'застрахователенилиев': 1,
#  'атрибутен': 2,
#  'поколението': 8,
#  'поддържате': 2,
#  'радков': 3,
#  'еволюиращи': 1,
#  'неистината': 1,
#  'установяват': 9,
#  'узреем': 1,
#  'таз…': 3,
#  'властови': 22,
#  'зверския': 7,
#  'сляпото': 18,
#  'стадото': 2,
#  'племеплеме': 1,
#  'португалски': 3,
#  'фалшификат': 1,
#  'кравешкото': 12,
#  'аполон': 5,
#  'ционисткия': 7,
#  'земля”': 2,
#  'hess': 3,
#  'близнаци\xa0на': 1,
#  'джеф': 22,
#  'външнополитическа': 25,
#  'необосновани': 2,
#  'проспани': 2,
#  'вселенският': 1,
#  'retro': 22,
#  'кожух': 20,
#  'градили': 8,
#  'роудс': 12,
#  'висококвалифицирани': 7,
#  'кобрат': 1,
#  'насърчаваше': 1,
#  'културно': 70,
#  'установила': 11,
#  'световете': 25,
#  'основателно': 6,
#  'участвуват': 1,
#  'положителна': 19,
#  'оплакват': 13,
#  'пoтъpcи': 1,
#  'образувала': 1,
#  'предприемат': 30,
#  'дръзнали': 1,
#  'ламот': 8,
#  'ting': 2,
#  'беритбата': 1,
#  'някoлкo': 3,
#  '\xa0ярките': 2,
#  'честният': 1,
#  'следващ': 14,
#  'осъществявали': 14,
#  'базира': 4,
#  'интензивно': 28,
#  'рафинирани': 1,
#  'януарски': 6,
#  'вложат': 13,
#  'пиенето': 12,
#  'ги\xa0': 1,
#  'остъпва': 1,
#  'неотлъчно': 4,
#  'даааа': 1,
#  'оглозгаха': 1,
#  'покупко': 13,
#  'радващо': 2,
#  'изкрещи': 1,
#  'построят': 12,
#  'асаду': 3,
#  'марксическа': 1,
#  'кент': 9,
#  'цирей': 1,
#  'mundus': 14,
#  'ставаха': 8,
#  'шeĸep': 2,
#  'мадама': 1,
#  'интимен': 2,
#  'противогрипни': 1,
#  'женският': 1,
#  'рейгънския': 1,
#  'сезан': 4,
#  'связанной': 2,
#  'очарованието': 3,
#  'юре': 6,
#  'снежана': 1,
#  '\xa0продължение': 2,
#  'посочват': 56,
#  'инеса': 1,
#  'оператор': 19,
#  'берлин\xa0людмила': 1,
#  'зах': 1,
#  'евангелист': 5,
#  'тоталната': 9,
#  'карта': 256,
#  'kartini': 1,
#  'ръждясали': 16,
#  'сепии': 1,
#  'присмехулник': 2,
#  'хотелската': 1,
#  'младо': 16,
#  '\xa0лорд': 1,
#  'рутинна': 5,
#  'вестникарския': 2,
#  'записвала': 5,
#  'прибираме': 3,
#  'дecиcлaвa': 1,
#  'еднообразие': 1,
#  'сън': 142,
#  'солдат': 1,
#  'отговорности': 2,
#  'аспект': 58,
#  'гледана': 2,
#  'продължават': 165,
#  'рафаело”': 1,
#  'добавка': 16,
#  'пророчествата': 119,
#  'неопределено': 15,
#  'неефективност': 1,
#  'преклонили': 2,
#  'индонезия': 35,
#  'бoлkи': 2,
#  'негласна': 3,
#  'димана': 1,
#  '•\xa0дж': 2,
#  'завидно': 7,
#  'компания': 122,
#  'ишиаса': 1,
#  'pais': 2,
#  'впечатленията': 5,
#  'патриарси': 1,
#  'закрилят': 1,
#  'британците': 41,
#  'славка': 15,
#  'арахангел': 2,
#  'допринесла': 1,
#  'несравнима': 1,
#  'изглеждащата': 3,
#  'търгуват': 3,
#  'подркепата': 1,
#  'дрянът': 1,
#  'българки': 25,
#  'говорещият': 4,
#  'домейна': 1,
#  'съдя': 2,
#  'изуш\xa0': 1,
#  'объркването': 1,
#  'мас': 2,
#  'боже': 47,
#  'дъно': 5,
#  'споходило': 1,
#  'изплашен': 15,
#  'татар»': 1,
#  'trymp': 1,
#  'пeтнo': 4,
#  'дупница': 5,
#  'стотинки': 11,
#  'насочили': 5,
#  'артериите': 2,
#  'балтаханов': 1,
#  'бeнзин': 2,
#  'европейско': 22,
#  'кефа': 6,
#  '\xa0гъpч': 2,
#  'дудите': 2,
#  'некрасиви': 1,
#  'внук': 50,
#  'книгоиздателска': 6,
#  'признанието': 16,
#  'рецесия': 4,
#  'ограбят': 5,
#  'информационната': 14,
#  '\xa0цялата': 1,
#  'госслужащих': 1,
#  'уличен': 2,
#  'нончев': 1,
#  'mining': 1,
#  'извършвало': 2,
#  'разгръща': 4,
#  'егейско': 16,
#  'съответна': 1,
#  'значение': 299,
#  'диана\xa0след': 1,
#  'ou': 6,
#  'кокошките': 3,
#  'прадедите': 2,
#  'норколут': 1,
#  'максималното': 7,
#  'пат': 10,
#  'рафики': 3,
#  'тенев': 1,
#  'мечтанието': 1,
#  'никанор': 1,
#  'ашли': 2,
#  'предполагает': 3,
#  'пейзажи': 3,
#  'пазарите': 7,
#  'преврата': 16,
#  'изживяваше': 3,
#  'студентите': 60,
#  'ап': 12,
#  'свиленград': 1,
#  'диктатора': 20,
#  'мутафова': 63,
#  'сборът': 2,
#  'споменава': 83,
#  'сегашния№': 1,
#  'първоразрядната': 1,
#  'садик': 1,
#  'начело': 101,
#  'битови': 4,
#  'възпитателната': 1,
#  'природе': 2,
#  '\xa0преимущественият': 1,
#  'оукланд': 1,
#  'люлките': 8,
#  'долу': 70,
#  'commons': 3,
#  'посрещнато': 1,
#  'пoчинaл': 2,
#  'крейтън': 3,
#  'кресненското': 3,
#  'едностранни': 2,
#  'търти': 3,
#  'лектори': 1,
#  'постъпката': 3,
#  'специализацията': 24,
#  'най‐застрашена': 1,
#  'канара': 2,
#  'реализираш': 1,
#  'одрисите': 1,
#  'андонова\xa0сътворява': 1,
#  'умеем': 1,
#  'солнце': 3,
#  'простых': 1,
#  'отмъщавам…': 7,
#  'начетеното': 2,
#  'виреенето': 1,
#  'руйно': 1,
#  'фолклорна': 2,
#  'erminia': 1,
#  'противогърчаво': 1,
#  'участвующих': 3,
#  'дебют': 3,
#  'сглобяване': 1,
#  'security': 2,
#  'anonymous': 24,
#  'нереалистични': 7,
#  '\xa0мнозина': 2,
#  'protestant': 1,
#  'родовата': 5,
#  'шърли': 3,
#  'скапани': 2,
#  'отговорна': 23,
#  'учредиха\xa0международния': 1,
#  'захвърлим': 1,
#  'дивана': 2,
#  'екстракти': 2,
#  'тшервена': 2,
#  'съобщение': 46,
#  'сипел': 5,
#  'dvd': 2,
#  'уфолог': 9,
#  'vyzlovoto': 1,
#  'действуват': 1,
#  'обещаят': 2,
#  'прибыль': 1,
#  'подпалва': 13,
#  'споделила': 62,
#  'гру': 22,
#  'умоляет': 1,
#  'трактати': 4,
#  'шкафа': 1,
#  'кравай': 7,
#  'мият': 3,
#  'наказателния': 1,
#  'свещенодейства': 3,
#  'живкова': 461,
#  'добавим': 19,
#  'умираше': 1,
#  'сша': 204,
#  'миротетшене': 1,
#  'centers': 1,
#  'късогледството': 1,
#  'fashisti': 1,
#  'страхлив': 6,
#  'забележат': 12,
#  'понася': 17,
#  'евгеника': 6,
#  'богомилската': 4,
#  'теб…': 2,
#  'просяк': 1,
#  'сатанинството': 1,
#  'незначещи': 1,
#  'пропагандист': 3,
#  'настояще': 14,
#  'нощни': 5,
#  'ступорът': 6,
#  'противопоставяния': 1,
#  'упоменато': 2,
#  'активизирайте': 3,
#  'избирали': 1,
#  'папирус': 1,
#  'томаш': 3,
#  'bohemiens': 2,
#  'готови': 158,
#  'избързахте': 1,
#  'развълнуван': 2,
#  'понесла': 6,
#  'читателя': 18,
#  'акад': 47,
#  'тръгнат': 72,
#  'електроуреди': 1,
#  'присадили': 1,
#  'паралелното': 2,
#  'прозират': 3,
#  'антивирусната': 1,
#  'приматско': 1,
#  'търсена': 3,
#  'съпътства': 2,
#  'демиургово': 1,
#  'занесъл': 1,
#  'трийсетгодишен': 1,
#  '‐': 5,
#  'разглобени': 1,
#  'изпада': 12,
#  'реформа': 33,
#  'водили': 34,
#  'метали\xa0в': 1,
#  '\xa0видяхте': 1,
#  'очаквам': 32,
#  'милиции': 9,
#  'папируси': 3,
#  'дисниленд': 2,
#  'притежава': 106,
#  'плачех': 3,
#  'изследователи': 83,
#  'изяждаме': 1,
#  'метеория”': 2,
#  'постоянни': 15,
#  'белот': 1,
#  'лъжците': 3,
#  'помагай': 2,
#  'отдаването': 1,
#  'нощите': 2,
#  'височки': 1,
#  'императиви': 2,
#  'светилището': 29,
#  'кусур': 1,
#  'разговорни': 1,
#  'инстанциите': 1,
#  'включвате': 1,
#  'представакакво': 1,
#  'кнесета': 2,
#  'топката': 3,
#  'проявата': 1,
#  'възприемана': 2,
#  'вестоносец': 26,
#  'подминавали': 1,
#  'предпочитания': 9,
#  'отрабатывать': 2,
#  'популистите': 3,
#  'лични': 67,
#  'фермер': 1,
#  'галактически': 1,
#  'бетц': 1,
#  'греша': 9,
#  'ментални': 6,
#  'смолянския': 5,
#  'cлeпи': 16,
#  'гилгамеш': 1,
#  'бенка\xa0историите': 3,
#  'иранци': 2,
#  'бунтовнически”': 3,
#  'цветни': 11,
#  'яви': 39,
#  'отзоват': 3,
#  'определиться': 3,
#  'maxkw': 1,
#  'изцеление': 31,
#  'халифи': 1,
#  'третирани': 7,
#  'означаващи': 1,
#  'вакуум': 12,
#  'откъсвате': 1,
#  'джагаров': 23,
#  'телепортираше': 1,
#  'облагородена”': 1,
#  'дънки': 3,
#  'тик': 1,
#  'делегитимират': 6,
#  'гробари': 1,
#  'рейтингът': 5,
#  'радиационни': 2,
#  'барнашка': 2,
#  'пратюркския\xa0монотеизъм': 2,
#  'неспецифично': 1,
#  'наличната': 2,
#  'постигнах': 1,
#  'охлаждат': 1,
#  'изядем': 3,
#  '\xa0силно': 1,
#  'kong': 2,
#  'подобно': 198,
#  'играта…поне': 2,
#  'оукс': 7,
#  'камери': 12,
#  'велосипедистите': 4,
#  'страхи': 2,
#  'бележи': 2,
#  'започвано': 2,
#  'заляха': 7,
#  'екранизацията': 2,
#  '\xa0жива': 1,
#  'сащ': 2774,
#  'продали': 7,
#  'бесконечной': 1,
#  'напът': 1,
#  'легален': 1,
#  'италианско': 1,
#  'оставил': 39,
#  'боси': 1,
#  'орешарските': 1,
#  'костват': 2,
#  'употребяваме': 8,
#  'лозенски': 22,
#  'обичаят': 3,
#  'элит»': 2,
#  'клубните': 1,
#  'военната': 69,
#  'християнин': 44,
#  'подписи': 3,
#  'проискряха': 1,
#  'никого”': 1,
#  'лейба': 2,
#  'спипат': 2,
#  'общности': 32,
#  'доминирате': 3,
#  'метеоритът': 5,
#  'сплетня': 1,
#  'предвижване': 6,
#  'мержелееше': 1,
#  'теонима': 1,
#  'съплеменници': 1,
#  'рубеж': 1,
#  'горещина': 2,
#  'городской': 2,
#  'барутните': 1,
#  'докоснем': 1,
#  'диоптъра': 1,
#  'пентаграмът': 1,
#  'cпpaви': 16,
#  'костюми': 11,
#  'емпиричните': 1,
#  'отразяването': 5,
#  'бачкат': 3,
#  'наследника': 4,
#  '№': 70,
#  'антиимпериалистическо': 1,
#  'кротко': 15,
#  'мориарти': 4,
#  'замазваници': 1,
#  'преимуществено': 2,
#  'преструва': 1,
#  'разюздани': 1,
#  'харвард”': 3,
#  'smiata': 1,
#  'връщам': 20,
#  'оттегля': 16,
#  'монарси': 12,
#  'окосена': 2,
#  'агенциите': 4,
#  'страж': 3,
#  'започваха': 5,
#  'хинов': 1,
#  'изискването': 3,
#  'рилийза': 3,
#  'дебютен': 2,
#  'слушател': 1,
#  'незасегнати': 4,
#  'бензинът': 1,
#  'coĸ': 2,
#  'величието': 21,
#  'кралев': 3,
#  'жены': 2,
#  'подслушва': 1,
#  'цитирано': 13,
#  'неведнъж': 52,
#  'посочения': 4,
#  'авиабазы': 3,
#  'отглеждам': 1,
#  'постинг\xa0значи': 1,
#  'бог\xa0перва\xa0при': 1,
#  'баалзебуб': 1,
#  'рисурс': 1,
#  'принадлежност': 16,
#  'orion': 1,
#  'кидош': 1,
#  'обвързвайте': 6,
#  'dare': 3,
#  'клонирано': 1,
#  'несправедливост': 23,
#  'adamite': 8,
#  'автомати\xa0': 1,
#  'властелин': 4,
#  'iudaismus': 2,
#  'регистрите': 2,
#  'всички\xa0': 2,
#  'природна': 3,
#  'урничката': 3,
#  'култивиран': 3,
#  'жермен': 32,
#  'наслагване': 1,
#  'компетентна': 2,
#  'ходих': 4,
#  'манхайм': 1,
#  'sofia': 4,
#  'различен': 96,
#  'никакво': 87,
#  'впечатляващия': 1,
#  'топонимни': 1,
#  'възникват': 8,
#  'лакти': 2,
#  'сурвакаря': 1,
#  'влияел': 1,
#  'притеснява': 18,
#  'опази': 10,
#  'кафява': 2,
#  'речете': 1,
#  'ловджийски': 2,
#  'креативните': 3,
#  'изтървах': 1,
#  'венозен': 1,
#  'идеологиите': 2,
#  'лаборатория': 27,
#  'неспирен': 1,
#  'опус': 10,
#  'духовни': 65,
#  'предположи': 15,
#  'caлaтa': 2,
#  'интелигентни': 13,
#  'но…': 14,
#  'дивният': 1,
#  'cтeпeн': 6,
#  'участнички': 5,
#  'забягнали': 6,
#  'престижния': 1,
#  'мобилизират': 6,
#  'доносниците': 3,
#  'задържани': 8,
#  'отговаряме': 4,
#  'заморские': 2,
#  'момински': 7,
#  'патриотите': 50,
#  'society': 2,
#  'зоната': 17,
#  'сензация': 19,
#  'стъпки\xa0се': 1,
#  'монолитен': 3,
#  'памятно': 2,
#  'откъснаха': 1,
#  'замислят': 22,
#  'кампрометиращи': 1,
#  '\xa0реалната': 7,
#  'паренето': 1,
#  'ожесточили': 1,
#  'smile': 1,
#  'monsanto': 4,
#  'обработвате': 1,
#  'казахте': 18,
#  'коствали': 7,
#  'детското': 3,
#  'генералисимус”': 3,
#  'повышая': 1,
#  'гравитационни': 2,
#  'първоизточникът': 1,
#  'революционна': 7,
#  'опознавателни': 1,
#  'познанията': 17,
#  'заспала': 12,
#  'блюдолизци': 1,
#  'белорус': 11,
#  'цюрихскими': 2,
#  'руни': 15,
#  'пишеше': 20,
#  'валят': 18,
#  'ed': 3,
#  'безумия': 9,
#  'рекламирането': 1,
#  'експеримент': 42,
#  'базах…': 1,
#  'трупащи': 1,
#  'малайзия\xa0не': 1,
#  'зарыта”': 2,
#  'бетовен': 4,
#  'охлюв': 4,
#  'изживели': 5,
#  'гласувам': 2,
#  'обобщението': 1,
#  'побити': 2,
#  'бледи': 3,
#  'престорите': 1,
#  'публично': 135,
#  'академичните': 2,
#  'светлинен': 2,
#  'прогнила': 1,
#  'крушари': 1,
#  'завладените': 1,
#  'преувеличена': 3,
#  'натискаш': 1,
#  'създадените': 8,
#  'навлиза': 13,
#  'иманярите': 8,
#  'калории': 4,
#  'размине': 5,
#  'фотографират': 1,
#  'dеѕѕоіr': 1,
#  'миналия': 79,
#  'радосвет': 1,
#  'посъбрали': 1,
#  'разгроми': 8,
#  'нараствал': 2,
#  'тресавището': 1,
#  'безмълвен': 5,
#  'засилят': 8,
#  'разменна': 1,
#  'norman': 1,
#  'ne': 5,
#  'нейвъл': 7,
#  'предизвиквайте': 1,
#  'макрина': 2,
#  'изпуснат': 5,
#  'heoбxoдими': 4,
#  'гроботърсачите”': 4,
#  'дезактивираха': 1,
#  'опять': 8,
#  '\xa0папата': 1,
#  'залавя': 7,
#  'допускаш': 5,
#  'записът': 4,
#  'видяx': 16,
#  'работят': 241,
#  'международный': 2,
#  'халф': 1,
#  'императриците': 1,
#  'студия': 1,
#  'самодоволната': 1,
#  'волските': 1,
#  'пурани': 1,
#  'гopcĸи': 2,
#  'озаглавено': 2,
#  'герчевпетричкият': 1,
#  'италиянският': 2,
#  'читателски': 1,
#  'сгъстяване': 2,
#  'требование': 2,
#  'християнска': 37,
#  'пристигне': 16,
#  'лъженауката': 5,
#  'национална': 114,
#  'градини”': 1,
#  'изследване”': 1,
#  'пеги': 1,
#  '\xa0петролният': 1,
#  'популисти': 2,
#  'косигин': 1,
#  'бюджети': 5,
#  'матери': 3,
#  'пораждаща': 2,
#  'подчертаят': 2,
#  'педер': 5,
#  'европески': 2,
#  'неизчерпаем': 5,
#  'зaщo': 1,
#  'отстраняват\xa0': 2,
#  'ацетат': 2,
#  'издивелите': 1,
#  'неточна': 3,
#  'отказът': 16,
#  'енурезис': 3,
#  'абсолвентския': 13,
#  'подло': 3,
#  'митничар': 3,
#  'заспиване': 24,
#  'ненормална': 2,
#  'изоставили': 5,
#  'async': 10,
#  'рафтове': 1,
#  '\xa0неотразимо': 1,
#  'твърде': 266,
#  'связывают': 2,
#  'севак': 2,
#  'косите': 7,
#  'михаел': 3,
#  'затъмняване': 1,
#  'завежда': 2,
#  'art': 5,
#  'разпилее': 2,
#  'са\xa0илюминатите': 1,
#  'дискета': 2,
#  'през': 5275,
#  'дъч': 2,
#  'мозъците': 29,
#  'цивилизационен\xa0потенциал': 1,
#  'опустошително': 7,
#  'таннакра': 1,
#  'обикновен': 43,
#  'джoджeн': 4,
#  'подготвената': 1,
#  'прекращения': 7,
#  'forced': 2,
#  'уестфийлд': 3,
#  'излекувах': 2,
#  'попия': 1,
#  'рпу': 1,
#  'рептилите': 75,
#  '•\xa0безпартийна': 2,
#  'новолунията': 1,
#  'словакия': 11,
#  'праведен': 5,
#  'но\xa0на': 1,
#  'препоръчително\xa0да': 1,
#  'сърдечна': 12,
#  'бънди': 2,
#  'граната': 5,
#  'териза': 1,
#  '\xa0влиятелни': 2,
#  'накаран': 1,
#  'случват': 103,
#  'надвишена': 2,
#  'клониране': 2,
#  'специални': 79,
#  'насилници': 1,
#  'сред\xa0милениум': 2,
#  'касабие': 1,
#  'водолазен': 1,
#  'луксор': 1,
#  'идиш': 2,
#  'bmw': 2,
#  'къпане': 9,
#  'разгледам': 7,
#  'проявява': 50,
#  'горният': 1,
#  'ръскин': 12,
#  'венци': 3,
#  'страх”': 1,
#  'вражеския': 3,
#  'безспорен': 13,
#  'стихове': 36,
#  'индоктринират': 6,
#  'тухличка': 1,
#  'вземането': 15,
#  'склонност': 25,
#  'клоуни\u2009—\u2009напротив': 1,
#  'завършваха': 3,
#  'непопулярното': 1,
#  'изтриват': 20,
#  'камчатка': 1,
#  'свръхвисш': 1,
#  'генетичната': 2,
#  'чуваше': 4,
#  'ходя': 25,
#  'направем': 1,
#  'линия': 219,
#  'странная': 2,
#  'отказахте': 4,
#  'палетата': 2,
#  'holy': 6,
#  'запълват': 5,
#  '\xa0бордът': 1,
#  'world': 24,
#  'формули': 25,
#  'toward': 1,
#  'паска': 2,
#  'сбъркала': 3,
#  'съзвездие': 15,
#  'калявах': 2,
#  'измирания': 1,
#  'кръстено': 8,
#  'оживено': 6,
#  'гигантската': 7,
#  'чхол': 6,
#  'просяшка': 2,
#  'кордовизползват': 1,
#  'иконописта': 1,
#  'скоропостижната\xa0': 2,
#  'oxford': 4,
#  'руй': 4,
#  'узнаваме': 2,
#  'лекарят': 6,
#  'военные': 8,
#  'всесилният': 3,
#  'слабоумието': 2,
#  'тутър': 1,
#  'измамните': 1,
#  'догматици': 1,
#  'вдигат': 43,
#  'лято”': 1,
#  'византийците': 9,
#  'съпротива': 32,
#  'глобализираната': 2,
#  'благодетел': 3,
#  'eвpo': 3,
#  'процъфтявала': 2,
#  'зaпoчвaмe': 2,
#  'интерес”': 2,
#  'πлaтнoтo': 2,
#  'расов': 3,
#  'противостоенето': 2,
#  'осиновяване': 1,
#  'удариха': 24,
#  'treasure”': 1,
#  'телешко': 5,
#  'тютюна': 24,
#  'нapязaни': 2,
#  'професори': 6,
#  'изкупят': 15,
#  'vereinigte': 1,
#  'отпечатам': 3,
#  'parc': 1,
#  'спрях': 5,
#  'спонсори': 13,
#  'ентусиазмът': 14,
#  'акта': 14,
#  'сензитивите': 2,
#  'контролиращ': 6,
#  'мoя': 16,
#  'хамбург': 2,
#  'раиса': 7,
#  'shell': 1,
#  'тихо\xa0': 2,
#  'вceĸи': 4,
#  'масачузетс': 5,
#  'ежеминутна': 2,
#  'мaйoнeзa': 2,
#  'андрюс': 4,
#  'неколкостотинте': 3,
#  'след': 4652,
#  'обезсилиш': 1,
#  'самопровъзгласил': 1,
#  'случаите”': 1,
#  'периоди': 51,
#  'оркестъра': 2,
#  'сътрудничество': 65,
#  'появиться': 2,
#  'отдельно': 2,
#  'масивната': 3,
#  'дребно”': 1,
#  'рисуван': 5,
#  'въздушното': 11,
#  'респективно': 8,
#  'ротондата': 4,
#  'младежки': 19,
#  'къщицана': 1,
#  'мигрира': 7,
#  'тръстове': 8,
#  'умилостивяване': 3,
#  'покрити': 4,
#  'лицемерно': 6,
#  'украинец': 2,
#  'размишляваме': 7,
#  'тристранна': 2,
#  'хрема': 1,
#  'затваря': 13,
#  'вътрешнопартийна': 4,
#  '\xa0песъчинки': 1,
#  'пазарлъци': 12,
#  'върнем': 70,
#  'винo': 6,
#  'ученички': 2,
#  'жертвените': 4,
#  'давам”': 1,
#  'марио': 39,
#  'собака': 2,
#  'gland': 4,
#  'скалата': 33,
#  'xpaмa': 1,
#  'превърнат': 46,
#  'икон': 1,
#  'разляти': 1,
#  'mojete': 1,
#  'инат': 5,
#  'свръхдържава': 6,
#  'сверхдержав': 2,
#  'knowledgeispower': 1,
#  'марияна': 28,
#  'запитани': 1,
#  '\xa0атаките': 1,
#  'ground': 4,
#  'еркан': 1,
#  'ателието': 1,
#  'судоку': 1,
#  'съргойчев': 1,
#  'глобализация': 14,
#  'общността': 9,
#  'лукавият': 1,
#  'първите': 228,
#  'разследването': 44,
#  'кауза': 32,
#  'санданчани': 2,
#  'предотвратил': 1,
#  'агитките': 1,
#  'славянските': 4,
#  'спинтрии': 1,
#  'средностатистически': 2,
#  'семантика': 3,
#  'експертите': 42,
#  'дам': 61,
#  'бибо': 1,
#  'усилению': 2,
#  'вавилонски': 3,
#  'российское': 1,
#  'po': 8,
#  ...}

# %%
from keras.callbacks import *
from keras.regularizers import l2
from keras.layers import Input, Embedding, LSTM, Dense, merge, TimeDistributed, Dropout, Lambda, Permute, Reshape, RepeatVector, Activation, Flatten

def attention(input_layer, n_units=256, maxlen=(20,20), name='attention'):
    k = 2 * n_units  # 300
    L = maxlen[0]  # 20
    N = sum(maxlen) + 1  # for delim
    gru_fwd = GRU(n_units, return_sequences=True, name=name+'_gru_fwd')(input_layer)
    gru_bwd = GRU(n_units, return_sequences=True, go_backwards=True, name=name+'_gru_bwd')(input_layer)
    bigru = merge([gru_fwd, gru_bwd], name=name+'_bigru', mode='concat')
    drop_out = Dropout(0.1)(bigru)
    h_n = Lambda(get_H_n, output_shape=(k,), name=name+"_h_n")(drop_out)
    Y = Lambda(get_Y, arguments={"xmaxlen": L}, name=name+"_Y", output_shape=(L, k))(drop_out)
    Whn = Dense(k, W_regularizer=l2(0.01), name=name+"_Wh_n")(h_n)
    Whn_x_e = RepeatVector(L, name=name+"_Wh_n_x_e")(Whn)
    WY = TimeDistributed(Dense(k, W_regularizer=l2(0.01)), name=name+"_WY")(Y)
    merged = merge([Whn_x_e, WY], name=name+"_merged", mode='sum')
    M = Activation('tanh', name=name+"_M")(merged)

    alpha_ = TimeDistributed(Dense(1, activation='linear'), name=name+"_alpha_")(M)
    flat_alpha = Flatten(name=name+"_flat_alpha")(alpha_)
    alpha = Dense(L, activation='softmax', name=name+"_alpha")(flat_alpha)

    Y_trans = Permute((2, 1), name=name+"_y_trans")(Y)  # of shape (None,300,20)

    r_ = merge([Y_trans, alpha], output_shape=(k, 1), name=name+"_r_", mode=get_R)

    r = Reshape((k,), name=name+"_r")(r_)
    Wr = Dense(k, W_regularizer=l2(0.01))(r)
    Wh = Dense(k, W_regularizer=l2(0.01))(h_n)
    return merge([Wr, Wh], mode='sum')
    #return Reshape((1, k))(merged)

def get_H_n(X):
    ans = X[:, -1, :]  # get last element from time dim
    return ans


def get_Y(X, xmaxlen):
    return X[:, :xmaxlen, :]  # get first xmaxlen elem from time dim


def get_R(X):
    Y, alpha = X[0], X[1]
    ans = K.batch_dot(Y, alpha)
    return ans

# %%
def create_model(num_words):
    seq_inp = Input(shape=(None,), dtype='int32', name='sequential_input')
    embedding = Embedding(num_words, 64, mask_zero=True)(seq_inp)
    rnn = Bidirectional(GRU(64, kernel_regularizer=l2(0.0001), recurrent_regularizer=l2(0.0001), bias_regularizer=l2(0.0001), 
                            recurrent_dropout=0.05, dropout=0.3, return_sequences=False))(embedding)
#     rnn = attention(rnn)
    rnn = Dense(1, activation='softmax')(rnn)
    
    return seq_inp, rnn

# %%
embedding_size = 64
num_words = tokenizer.num_words

## Words
model_input, model_output = create_model(num_words)
model = Model(inputs=[model_input], outputs=model_output)

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_input (InputLayer (None, None)              0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, None, 64)          640000
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 128)               49536
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 689,665
# Trainable params: 689,665
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(model, to_file='model_gru.png', show_shapes=True)

# %%
from IPython.display import Image
Image("model_gru.png")

# %%
train.Content.apply(lambda t: len(t.split())).hist(bins=100)

# %%
def batch_generator(df, n=100, is_shuffle=True):
    
    l = len(df)
    while True:
        
        if is_shuffle:
            df = shuffle(df)

        for ndx in range(0, l, n):
            x = df.Content

            
            _x = tokenizer.texts_to_sequences(x[ndx:min(ndx + n, l)])
            maxlen = min(max(map(len, _x)), 2000)
            _x = sequence.pad_sequences(_x, maxlen=maxlen)

            
                
            yield _x, train.fake_news_score[ndx:min(ndx + n, l)] == 3

# %%
# %%time
from datetime import datetime
now = datetime.now()
experiment_name = 'exp_rnn_attention'
log_dir = 'logs/' + now.strftime("%Y%m%d-%H%M%S-") + experiment_name + "/"

tensorboard = TensorBoard(log_dir=log_dir, histogram_freq=0.1, write_graph=True, write_images=False)
checkpointer = ModelCheckpoint(filepath="models_checkpoints/" + experiment_name + ".hdf5", verbose=1, save_best_only=True)
batch_size = 100

history = model.fit_generator(batch_generator(train, n=batch_size), 
                              epochs=10,
                              initial_epoch=0, 
                              steps_per_epoch = len(train) // batch_size,
                              validation_data=batch_generator(test, n=batch_size, is_shuffle=False),
                              validation_steps=len(test) // batch_size,
                              callbacks=[tensorboard, checkpointer])

history_temp = history
# Out:
# INFO:tensorflow:Summary name embedding_1/embeddings:0 is illegal; using embedding_1/embeddings_0 instead.
# INFO:tensorflow:Summary name bidirectional_1/forward_gru_1/kernel:0 is illegal; using bidirectional_1/forward_gru_1/kernel_0 instead.
# INFO:tensorflow:Summary name bidirectional_1/forward_gru_1/recurrent_kernel:0 is illegal; using bidirectional_1/forward_gru_1/recurrent_kernel_0 instead.
# INFO:tensorflow:Summary name bidirectional_1/forward_gru_1/bias:0 is illegal; using bidirectional_1/forward_gru_1/bias_0 instead.
# INFO:tensorflow:Summary name bidirectional_1/backward_gru_1/kernel:0 is illegal; using bidirectional_1/backward_gru_1/kernel_0 instead.
# INFO:tensorflow:Summary name bidirectional_1/backward_gru_1/recurrent_kernel:0 is illegal; using bidirectional_1/backward_gru_1/recurrent_kernel_0 instead.
# INFO:tensorflow:Summary name bidirectional_1/backward_gru_1/bias:0 is illegal; using bidirectional_1/backward_gru_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# Epoch 1/10
# 18/25 [====================>.........] - ETA: 115s - loss: 4.9821 - acc: 0.6883
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>()
#
# /Users/lacho/.pyenv/versions/3.5.1/envs/hack_fake_news/lib/python3.5/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      86                 warnings.warn('Update your `' + object_name +
#      87                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 88             return func(*args, **kwargs)
#      89         wrapper._legacy_support_signature = inspect.getargspec(func)
#      90         return wrapper
#
# /Users/lacho/.pyenv/versions/3.5.1/envs/hack_fake_news/lib/python3.5/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_q_size, workers, pickle_safe, initial_epoch)
#    1888                     outs = self.train_on_batch(x, y,
#    1889                                                sample_weight=sample_weight,
# -> 1890                                                class_weight=class_weight)
#    1891
#    1892                     if not isinstance(outs, list):
#
# /Users/lacho/.pyenv/versions/3.5.1/envs/hack_fake_news/lib/python3.5/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1631             ins = x + y + sample_weights
#    1632         self._make_train_function()
# -> 1633         outputs = self.train_function(ins)
#    1634         if len(outputs) == 1:
#    1635             return outputs[0]
#
# /Users/lacho/.pyenv/versions/3.5.1/envs/hack_fake_news/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2227         session = get_session()
#    2228         updated = session.run(self.outputs + [self.updates_op],
# -> 2229                               feed_dict=feed_dict)
#    2230         return updated[:len(self.outputs)]
#    2231
#
# /Users/lacho/.pyenv/versions/3.5.1/envs/hack_fake_news/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/lacho/.pyenv/versions/3.5.1/envs/hack_fake_news/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# /Users/lacho/.pyenv/versions/3.5.1/envs/hack_fake_news/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/lacho/.pyenv/versions/3.5.1/envs/hack_fake_news/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# /Users/lacho/.pyenv/versions/3.5.1/envs/hack_fake_news/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
