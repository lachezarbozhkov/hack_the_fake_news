# %%
from gensim.models import LdaModel
from gensim.corpora import Dictionary

fake_dict = Dictionary.load('/home/pepa/Downloads/dict')
lda = LdaModel.load("/home/pepa/Downloads/lda/lda_model")
# Out:
# /usr/lib/python3.5/json/encoder.py:198: DeprecationWarning: Interpreting naive datetime as local 2017-05-21 12:31:04.004446. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

data = pd.read_excel('/home/pepa/git/hack_the_fake_news/data/FN_Training_Set.xlsx')
corpus = [fake_dict.doc2bow(str(sent).lower().split(" ")) for sent in data['Content Title']]
# Out:
# /usr/lib/python3.5/json/encoder.py:198: DeprecationWarning: Interpreting naive datetime as local 2017-05-21 12:38:51.793423. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
import pyLDAvis.gensim as gensimvis
import pyLDAvis

vis_data = gensimvis.prepare(lda, corpus, fake_dict)
pyLDAvis.display(vis_data, )
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el149131397841825781769886501016"></div>
# <script type="text/javascript">
#
# ...
